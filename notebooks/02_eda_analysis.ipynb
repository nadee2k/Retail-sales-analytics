# %%
# %pip install matplotlib
import matplotlib.pyplot as plt
import pandas as pd

# load cleaned data created by the cleaning notebook
if 'df' not in globals():
    df = pd.read_csv('../data/cleaned_data.csv')

monthly_sales = df.groupby('order_month')['Sales'].sum()

monthly_sales.plot(figsize=(10,5))
plt.title("Monthly Revenue Trend")
plt.ylabel("Total Sales")
plt.show()
# Out:
# Requirement already satisfied: matplotlib in /home/Dhananjana/GitHub/Retail-sales-analytics/venv/lib64/python3.14/site-packages (3.10.8)
# Requirement already satisfied: contourpy>=1.0.1 in /home/Dhananjana/GitHub/Retail-sales-analytics/venv/lib64/python3.14/site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /home/Dhananjana/GitHub/Retail-sales-analytics/venv/lib64/python3.14/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/Dhananjana/GitHub/Retail-sales-analytics/venv/lib64/python3.14/site-packages (from matplotlib) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/Dhananjana/GitHub/Retail-sales-analytics/venv/lib64/python3.14/site-packages (from matplotlib) (1.4.9)
# Requirement already satisfied: numpy>=1.23 in /home/Dhananjana/GitHub/Retail-sales-analytics/venv/lib64/python3.14/site-packages (from matplotlib) (2.4.2)
# Requirement already satisfied: packaging>=20.0 in /home/Dhananjana/GitHub/Retail-sales-analytics/venv/lib64/python3.14/site-packages (from matplotlib) (26.0)
# Requirement already satisfied: pillow>=8 in /home/Dhananjana/GitHub/Retail-sales-analytics/venv/lib64/python3.14/site-packages (from matplotlib) (12.1.1)
# Requirement already satisfied: pyparsing>=3 in /home/Dhananjana/GitHub/Retail-sales-analytics/venv/lib64/python3.14/site-packages (from matplotlib) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /home/Dhananjana/GitHub/Retail-sales-analytics/venv/lib64/python3.14/site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /home/Dhananjana/GitHub/Retail-sales-analytics/venv/lib64/python3.14/site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
#
# [notice] A new release of pip is available: 25.1.1 -> 26.0.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
plt.savefig("../visuals/monthly_revenue.png")

# %%
region_sales = df.groupby('Region')['Sales'].sum().sort_values(ascending=False)
region_sales.plot(kind='bar')
plt.title("Sales by Region")
plt.show()

# %%
top_products = df.groupby('Product Name')['Sales'].sum().sort_values(ascending=False).head(10)
top_products.plot(kind='barh')
plt.title("Top 10 Products by Revenue")
plt.show()

# %%
aov = df['Sales'].sum() / df['Order ID'].nunique()
print("Average Order Value:", round(aov,2))
# Out:
# Average Order Value: 458.61

# %%
customer_orders = df.groupby('Customer ID')['Order ID'].nunique()
repeat_rate = (customer_orders > 1).mean()
print("Repeat Customer Rate:", round(repeat_rate*100,2), "%")
# Out:
# Repeat Customer Rate: 98.49 %
